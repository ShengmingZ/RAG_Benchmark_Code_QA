# %%
import json
from run_model import chatgpt
from sparse_retriever import sparse_retriever_config

# %%
bm25_args = sparse_retriever_config("")
ret_result_bm25_tldr_whole = json.load(open(bm25_args.tldr_ret_result_whole, 'r'))
ret_result_bm25_tldr_line = json.load(open(bm25_args.tldr_ret_result_line, 'r'))
tldr_qs = json.load(open(bm25_args.tldr_qs_file, 'r'))
tldr_doc_whole = json.load(open(bm25_args.tldr_doc_whole, 'r'))
tldr_doc_line = json.load(open(bm25_args.tldr_doc_line, 'r'))

# %%
tldr_qs[0]
test_qs = tldr_qs[0]['nl']

# %%
top_k_cmd = 2
top_k_line = 5
test_ret_cmd = [ret_result['lib_key'] for ret_result in ret_result_bm25_tldr_whole[0][0:top_k_cmd]]
test_ret_cmd_line = list()
for k in range(0,top_k_cmd):
    test_ret_cmd_line.extend([ret_result['lib_key'] for ret_result in ret_result_bm25_tldr_line[0][k][0:top_k_line]])

# %%
print(test_ret_cmd)
print(test_ret_cmd_line)
# Out:
# ['neofetch', 'screenfetch']
# ['neofetch_93', 'neofetch_90', 'neofetch_92', 'neofetch_102', 'neofetch_78', 'screenfetch_23', 'screenfetch_3', 'screenfetch_26', 'screenfetch_16', 'screenfetch_15']

# %%
ret_docs = list()
for idx, cmd_line in enumerate(test_ret_cmd_line):
    ret_docs.append(f"potential document {idx}: {cmd_line}: {tldr_doc_line[cmd_line]}")

# %%
prompt = '''Potential document 0: fatlabel_3: fatlabel will display or change the volume label or volume ID on the MS- DOS filesystem located on DEVICE.  By default it works in label mode.  It can be switched to volume ID mode with the option -i or --volume-id.
# get the label of a fat32 partition
fatlabel {{/dev/sda1}}

#END

Potential document 0: w_3: w displays information about the users currently on the machine, and their processes.  The header shows, in this order, the current time, how long the system has been running, how many users are currently logged on, and the system load averages for the past 1, 5, and 15 minutes.
Potential document 1: w_9: -s, --short Use the short format.  Don't print the login time, JCPU or PCPU times.
# display information without including the login, jcpu and pcpu columns
w --short

#END

Potential document 0: csvsort_2: Sort CSV files. Like the Unix “sort” command, but for tabular data:
Potential document 1: csvsort_3: usage: csvsort [-h] [-d DELIMITER] [-t] [-q QUOTECHAR] [-u {0,1,2,3}] [-b] [-p ESCAPECHAR] [-z FIELD_SIZE_LIMIT] [-e ENCODING] [-L LOCALE] [-S] [--blanks] [--date-format DATE_FORMAT] [--datetime-format DATETIME_FORMAT] [-H] [-K SKIP_LINES] [-v] [-l] [--zero] [-V] [-n] [-c COLUMNS] [-r] [-y SNIFF_LIMIT] [-I
Potential document 2: csvsort_6: optional arguments: -h, --help            show this help message and exit -n, --names           Display column names and indices from the input CSV and exit. -c COLUMNS, --columns COLUMNS A comma separated list of column indices, names or ranges to sort by, e.g. "1,id,3-5". Defaults to all columns. -r, --reverse         Sort in descending order. -y SNIFF_LIMIT, --snifflimit SNIFF_LIMIT Limit CSV dialect sniffing to the specified number of bytes. Specify "
Potential document 3: csvsort_10: csvsort -c 9 examples/realdata/FY09_EDU_Recipients_by_State.csv
Potential document 4: csvsort_12: csvcut -c 1,9 examples/realdata/FY09_EDU_Recipients_by_State.csv | csvsort -r -c 2 | head -n 5
# sort a csv file by column 9
csvsort -c {{9}} {{data.csv}}

#END'''

# %%
prompt += '\n'
for doc in ret_docs:
    prompt += doc
    prompt += '\n'
prompt += f'# {test_qs}'

# %%
print(prompt)
# Out:
# Potential document 0: fatlabel_3: fatlabel will display or change the volume label or volume ID on the MS- DOS filesystem located on DEVICE.  By default it works in label mode.  It can be switched to volume ID mode with the option -i or --volume-id.
# # get the label of a fat32 partition
# fatlabel {{/dev/sda1}}
#
# #END
#
# Potential document 0: w_3: w displays information about the users currently on the machine, and their processes.  The header shows, in this order, the current time, how long the system has been running, how many users are currently logged on, and the system load averages for the past 1, 5, and 15 minutes.
# Potential document 1: w_9: -s, --short Use the short format.  Don't print the login time, JCPU or PCPU times.
# # display information without including the login, jcpu and pcpu columns
# w --short
#
# #END
#
# Potential document 0: csvsort_2: Sort CSV files. Like the Unix “sort” command, but for tabular data:
# Potential document 1: csvsort_3: usage: csvsort [-h] [-d DELIMITER] [-t] [-q QUOTECHAR] [-u {0,1,2,3}] [-b] [-p ESCAPECHAR] [-z FIELD_SIZE_LIMIT] [-e ENCODING] [-L LOCALE] [-S] [--blanks] [--date-format DATE_FORMAT] [--datetime-format DATETIME_FORMAT] [-H] [-K SKIP_LINES] [-v] [-l] [--zero] [-V] [-n] [-c COLUMNS] [-r] [-y SNIFF_LIMIT] [-I
# Potential document 2: csvsort_6: optional arguments: -h, --help            show this help message and exit -n, --names           Display column names and indices from the input CSV and exit. -c COLUMNS, --columns COLUMNS A comma separated list of column indices, names or ranges to sort by, e.g. "1,id,3-5". Defaults to all columns. -r, --reverse         Sort in descending order. -y SNIFF_LIMIT, --snifflimit SNIFF_LIMIT Limit CSV dialect sniffing to the specified number of bytes. Specify "
# Potential document 3: csvsort_10: csvsort -c 9 examples/realdata/FY09_EDU_Recipients_by_State.csv
# Potential document 4: csvsort_12: csvcut -c 1,9 examples/realdata/FY09_EDU_Recipients_by_State.csv | csvsort -r -c 2 | head -n 5
# # sort a csv file by column 9
# csvsort -c {{9}} {{data.csv}}
#
# #END
# potential document 0: neofetch_93: --ascii_distro distro Which Distro's ascii art to print
# potential document 1: neofetch_90: --off  Shortcut to use 'off' backend (Disable ascii art).
# potential document 2: neofetch_92: ASCII: --ascii_colors x x x x x x Colors to print the ascii art
# potential document 3: neofetch_102: -L, --logo Hide the info text and only show the ascii logo.
# potential document 4: neofetch_78: --ascii source Shortcut to use 'ascii' backend.
# potential document 5: screenfetch_23: -a 'PATH' You can specify a custom ASCII art by passing the path to a Bash script, defining startline and fulloutput variables, and optionally labelcolor and textcolor. See the asciiText function in the source code for more information on the variables format.
# potential document 6: screenfetch_3: This handy Bash script can be used to generate one of those nifty terminal theme information + ASCII distribution logos you see in everyone's screenshots nowadays. It will auto-detect your distribution and display an ASCII version of that distribution's logo and some valuable information to the right. There are options to specify no ASCII art, colors, taking a screenshot upon displaying info, and even customizing the screenshot command!  This script is very easy to add to and can easily be extended.
# potential document 7: screenfetch_26: -A 'DISTRO' Here you can specify the distribution art that you want displayed. This is for when you want your distro detected but want to display a different logo.
# potential document 8: screenfetch_16: -L     Display ASCII distribution logo only.
# potential document 9: screenfetch_15: -n     Do not display ASCII distribution logo.
# # generate ascii art for a given text

# %%
chatgpt(prompt)
# Out:
# ['neofetch --ascii_distro {{distro}}']
